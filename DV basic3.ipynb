# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cols=['CreditScore','Geography',
'Gender','Age','Tenure',
'Balance','NumOfProducts',
'IsActiveMember','EstimatedSalary','Exited']
churn=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\archive (2)\\Churn_Modelling.csv",usecols=cols)
churn.head()
churn.tail()
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       IsActiveMember  EstimatedSalary  Exited
# 9995               0         96270.64       0
# 9996               1        101699.77       0
# 9997               1         42085.58       1
# 9998               0         92888.52       1
# 9999               0         38190.78       0

# %%
churn['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
type(churn['Geography'].value_counts())
# Out:
# pandas.Series

# %%
Customer_per_Country=dict(churn['Geography'].value_counts())
Customer_per_Country
# Out:
# {'France': np.int64(5014), 'Germany': np.int64(2509), 'Spain': np.int64(2477)}

# %%
total=sum(churn['Geography'].value_counts().values)

# %%
plt.pie(list(Customer_per_Country.values()),labels=Customer_per_Country.keys())
plt.show()

# %%
colors=['red','orange','skyblue']
plt.pie(list(Customer_per_Country.values()),labels=Customer_per_Country.keys(),
colors=colors,shadow=False,startangle=90)
plt.axis('equal')
plt.show()

# %%
churn['NumOfProducts'].value_counts()
# Out:
# NumOfProducts
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: count, dtype: int64

# %%
type(churn['NumOfProducts'].value_counts())
# Out:
# pandas.Series

# %%
Customer_per_Country=dict(churn['NumOfProducts'].value_counts())
Customer_per_Country
# Out:
# {1: np.int64(5084), 2: np.int64(4590), 3: np.int64(266), 4: np.int64(60)}

# %%
colors = ['green','pink','skyblue','blue']
plt.pie(list(Customer_per_Country.values()),
labels=Customer_per_Country.keys(),colors=colors, shadow=False, startangle=90)
plt.show()

# %%
import matplotlib.pyplot as plt

# Your data and settings
colors = ['green', 'pink', 'skyblue', 'blue']
highlight = (0, 0, 0.1, 0)  # This "explodes" the 3rd slice

# Corrected plt.pie call
plt.pie(
    list(Customer_per_Country.values()), 
    labels=Customer_per_Country.keys(), 
    explode=highlight, 
    colors=colors,
    autopct='%1.1f%%' # Optional: adds percentage labels to slices
)

plt.show()
